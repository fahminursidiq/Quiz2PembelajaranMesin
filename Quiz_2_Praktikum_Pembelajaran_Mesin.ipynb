# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2d97fa3-7c86-4320-aba2-0c8236369f20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2d97fa3-7c86-4320-aba2-0c8236369f20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving netflix.csv to netflix.csv

# %%
import pandas as pd
df = pd.read_csv('netflix.csv')
print(df)
# Out:
#                              Title                             Genre  \
# 0                  Stranger Things            Science fiction/horror
# 1                        The Crown                  Historical drama
# 2                            Ozark                       Crime drama
# 3             The Umbrella Academy                  Superhero action
# 4                     Black Summer         Apocalyptic fiction drama
# ..                             ...                               ...
# 358                         Arcane  Animated science fiction fantasy
# 359  Juanpis González – The Series                            Comedy
# 360               Awaiting release                  Awaiting release
# 361            Pedal to Metal[168]                            Action
# 362      Power Rangers (season 29)         Science fiction/Superhero
#
#              Language           Premiere           Runtime  \
# 0             English      July 15, 2016         42–78 min
# 1             English   November 4, 2016         47–61 min
# 2             English      July 21, 2017         50–80 min
# 3             English  February 15, 2019         40–60 min
# 4             English     April 11, 2019         21–58 min
# ..                ...                ...               ...
# 358           English   November 6, 2021         39–44 min
# 359           Spanish   January 19, 2022            25 min
# 360  Awaiting release   Awaiting release  Awaiting release
# 361           Spanish     March 16, 2022               TBA
# 362           English      March 3, 2022            22 min
#
#                     Seasons
# 0    3 seasons, 25 episodes
# 1    4 seasons, 40 episodes
# 2    4 seasons, 37 episodes
# 3    2 seasons, 20 episodes
# 4    2 seasons, 16 episodes
# ..                      ...
# 358    1 season, 9 episodes
# 359   1 season, 10 episodes
# 360        Awaiting release
# 361                     TBA
# 362   1 season, 22 episodes
#
# [363 rows x 6 columns]

# %%
df.head()
# Out:
#                   Title                      Genre Language  \
# 0       Stranger Things     Science fiction/horror  English
# 1             The Crown           Historical drama  English
# 2                 Ozark                Crime drama  English
# 3  The Umbrella Academy           Superhero action  English
# 4          Black Summer  Apocalyptic fiction drama  English
#
#             Premiere    Runtime                 Seasons
# 0      July 15, 2016  42–78 min  3 seasons, 25 episodes
# 1   November 4, 2016  47–61 min  4 seasons, 40 episodes
# 2      July 21, 2017  50–80 min  4 seasons, 37 episodes
# 3  February 15, 2019  40–60 min  2 seasons, 20 episodes
# 4     April 11, 2019  21–58 min  2 seasons, 16 episodes

# %%
print(df.dtypes)
# Out:
# Title       object
# Genre       object
# Language    object
# Premiere    object
# Runtime     object
# Seasons     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     361 non-null    object
#  1   Genre     326 non-null    object
#  2   Language  363 non-null    object
#  3   Premiere  361 non-null    object
#  4   Runtime   361 non-null    object
#  5   Seasons   361 non-null    object
# dtypes: object(6)
# memory usage: 17.1+ KB

# %%
df.describe()
# Out:
#                    Title       Genre Language          Premiere Runtime  \
# count                361         326      363               361     361
# unique               347         111       17               266     262
# top     Awaiting release  Docuseries  English  Awaiting release     TBA
# freq                  15          23      289                15      29
#
#                      Seasons
# count                    361
# unique                    84
# top     1 season, 8 episodes
# freq                      68

# %%
df.count()
# Out:
# Title       361
# Genre       326
# Language    363
# Premiere    361
# Runtime     361
# Seasons     361
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                    Title       Genre Language          Premiere Runtime  \
# count                361         326      363               361     361
# unique               347         111       17               266     262
# top     Awaiting release  Docuseries  English  Awaiting release     TBA
# freq                  15          23      289                15      29
#
#                      Seasons
# count                    361
# unique                    84
# top     1 season, 8 episodes
# freq                      68

# %%
df.fillna(0)
# Out:
#                              Title                             Genre  \
# 0                  Stranger Things            Science fiction/horror
# 1                        The Crown                  Historical drama
# 2                            Ozark                       Crime drama
# 3             The Umbrella Academy                  Superhero action
# 4                     Black Summer         Apocalyptic fiction drama
# ..                             ...                               ...
# 358                         Arcane  Animated science fiction fantasy
# 359  Juanpis González – The Series                            Comedy
# 360               Awaiting release                  Awaiting release
# 361            Pedal to Metal[168]                            Action
# 362      Power Rangers (season 29)         Science fiction/Superhero
#
#              Language           Premiere           Runtime  \
# 0             English      July 15, 2016         42–78 min
# 1             English   November 4, 2016         47–61 min
# 2             English      July 21, 2017         50–80 min
# 3             English  February 15, 2019         40–60 min
# 4             English     April 11, 2019         21–58 min
# ..                ...                ...               ...
# 358           English   November 6, 2021         39–44 min
# 359           Spanish   January 19, 2022            25 min
# 360  Awaiting release   Awaiting release  Awaiting release
# 361           Spanish     March 16, 2022               TBA
# 362           English      March 3, 2022            22 min
#
#                     Seasons
# 0    3 seasons, 25 episodes
# 1    4 seasons, 40 episodes
# 2    4 seasons, 37 episodes
# 3    2 seasons, 20 episodes
# 4    2 seasons, 16 episodes
# ..                      ...
# 358    1 season, 9 episodes
# 359   1 season, 10 episodes
# 360        Awaiting release
# 361                     TBA
# 362   1 season, 22 episodes
#
# [363 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     361 non-null    object
#  1   Genre     326 non-null    object
#  2   Language  363 non-null    object
#  3   Premiere  361 non-null    object
#  4   Runtime   361 non-null    object
#  5   Seasons   361 non-null    object
# dtypes: object(6)
# memory usage: 17.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
